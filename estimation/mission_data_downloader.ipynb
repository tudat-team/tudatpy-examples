# %% [markdown]
# ## Objectives
#
# This script allows to download:
# 1) Spice (clock, frame, orientation, planetary) Kernels
# 2) Closed Loop Doppler Data (DSN and IFMS)
# 3) Ancillary Ionospheric and Tropospheric Data
#
# **NOTE 1 (Supported Missions and Relative Downloaded Data).**
#
# The following spice kernels:
#
# 1) **existing spice kernels** in the mission folder
# 2) (new) **downloaded spice kernels**
# 3) **standard TUDAT kernels** from [`spice.load_standard_kernels()`](https://py.api.tudat.space/en/latest/spice.html#tudatpy.interface.spice.load_standard_kernels)
#
# are loaded at the end of a run (some information is printed as output).
#
# List of currently supported input_missions:
# - **Mars Reconnnaissance Orbiter (MRO)** [Available: Spice Kernels, Doppler Data, Ancillary]
# - **Mars Express (MEX)** [Available: Spice Kernels, Doppler Data, Ancillary]
# - **Jupiter Icy Moons Explorer (JUICE)** [Available: Spice Kernels, Not Available (yet): Doppler Data, Ancillary]
# - **Cassini**
# - **GRAIL (both Grail-A and Grail-B)**
#
# Foreseen supported missions (in descending priority order, code yet to be developed):
#
# - Insight
# - VEX
# - LRO
#
# **NOTE 2. (Default and Custom Outputs)**
#
# The downloaded data for a given mission is stored (by default) in a folder named `<mission_name>_archive`. Subfolders are created automatically where Kernels, Radio Science Data and Ancillary Data are stored.
# The user can still define a custom output path passing the flag `custom_output` in the `get_mission_files` function. The output files will then be found in: `custom_path`
#
# **NOTE 3. (About DSN-TNF)**
#
# No DSN-TNF download functionality has been implemented (at least, not yet!)
#
# **Note 4: About spiceypy**
#
# A compiled version of TUDAT containing the `spiceypy` dependency is needed (if spiceypy is not present, you won't be able to download files for the Cassini mission)

# %% [markdown]
# ## Load required standard modules
# The required modules and dependencies are taken from the python file: `Mission_Data_Retriever_Class.py` present in the`tudatpy-examples/estimation` folder.

# %%
from mission_data_downloader_class import *

# %% [markdown]
# ## Create the LoadPDS Object
# First, we create the LoadPDS() object.

# %%
object = LoadPDS()
spice.clear_kernels() #lets clear the kernels to avoid duplicates,since we will load all standard + Downloaded + existing kernels

# %% [markdown]
# ## MRO Downloader (with Default Output)
#
# ### Set Time Interval(s) for Downloading
#
# Then we select the `start_date` and `end_date`, and we do so for each mission we wish to download (Cassini will be an exception due to the peculiar mission concept, see **Cassini Downloader** below). Of course, each mission has to come with its own dates, as operations are carried out over different periods.
#
# ### Download Mission Files (MRO, MEX, JUICE)
# Finally, we can call the function "get_mission_files".
# get_mro_files will download: clock kernels, orientation kernels, radio science (odf) files for mro
# get_mex_files will download: clock kernels, orientation kernels, radio science (ifms) files for mex
# get_juice_files will download: clock kernels, orientation kernels, for juice. No radio science data, cause none is yet available on the server (fdets retrieval is needed).
#
# **Note 5 (About MEX and JUICE Files Download)**
#
# Here, we will only showcase the downloading of MRO files. However, **if you wish to download files for MEX or JUICE**, you can simply **uncomment the corresponding lines** in the cell below! We have included those **just for you**!

# %%
start_date_juice = datetime(2023, 7, 1)
end_date_juice = datetime(2023, 8, 10)

start_date_mro = datetime(2007, 1, 3)
end_date_mro = datetime(2007, 1, 5)

start_date_mex = datetime(2004, 1, 3)
end_date_mex = datetime(2004,2, 7) 

# Download Mission Files with default output folder
# (only MRO is shown here. Uncomment the corresponding lines to download data for MEX and JUICE!)

kernel_files_mro, radio_science_files_mro, ancillary_files_mro = object.get_mission_files(input_mission = 'mro', start_date = start_date_mro, end_date = end_date_mro, custom_output = None)         
print(f'Total number of loaded kernels: {spice.get_total_count_of_kernels_loaded()}')

kernel_files_mex, radio_science_files_mex, ancillary_files_mex = object.get_mission_files(input_mission = 'mex', start_date = start_date_mex, end_date = end_date_mex)         
print(f'Total number of loaded kernels: {spice.get_total_count_of_kernels_loaded()}')

kernel_files_juice, radio_science_files_juice, ancillary_files_juice = object.get_mission_files(input_mission = 'juice', start_date = start_date_juice, end_date = end_date_juice) 
print(f'Total number of loaded kernels: {spice.get_total_count_of_kernels_loaded()}')
# Out:
# ======================================= Downloading MRO Data ==============================================
#
# =========================================== Folder(s) Creation ==================================================
# Folder: mro_archive/ already exists and will not be overwritten.
# ===============================================================================================================
#
# ===========================================================================================================
# Download MRO ODF files:
# Checking URL: https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/
# --------------------------------------- EXISTING FILES CHECK ----------------------------------------------
# The following files already exist in the folder:
#
#  ['mro_archive/odf/mromagr2007_004_1801xmmmv1.odf', 'mro_archive/odf/mromagr2007_003_0845xmmmv1.odf']
#
#  and will not be downloaded.
# ...Done.
# ===========================================================================================================
# Download MRO Clock Kernels:
# File: mro_archive/sclk/mro_sclkscet_00112_65536.tsc already exists in: mro_archive/ and will not be downloaded.
# ===========================================================================================================
# Download MRO Frame Kernels:
# File: mro_archive/fk/mro_v16.tf already exists in: mro_archive/ and will not be downloaded.
# ===========================================================================================================
# Download MRO SPK Kernels:
# File: mro_archive/spk/mro_psp2.bsp already exists in: mro_archive/ and will not be downloaded.
# File: mro_archive/spk/mro_struct_v10.bsp already exists in: mro_archive/ and will not be downloaded.
# ===========================================================================================================
# Download MRO Orientation Kernels:
# Checking URL: https://naif.jpl.nasa.gov/pub/naif/pds/data/mro-m-spice-6-v1.0/mrosp_1000/data/ck/
# --------------------------------------- EXISTING FILES CHECK ---------------------------------------------
#
# The following files already exist in the folder:
#
#  ['mro_archive/ck/mro_sc_psp_070102_070108.bc']
#
#  and will not be downloaded.
# ...Done.
# ===========================================================================================================
# Download MRO Tropospheric Corrections Files
# Checking URL: https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/ancillary/tro/
# --------------------------------------- EXISTING FILES CHECK ---------------------------------------------
#
# The following files already exist in the folder:
#
#  ['mro_archive/tro/mromagr2007_001_2007_032.tro']
#
#  and will not be downloaded.
# ...Done.
# ===========================================================================================================
# Download MRO Ionospheric Corrections Files
# Checking URL: https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/ancillary/ion/
# --------------------------------------- EXISTING FILES CHECK ---------------------------------------------
#
# The following files already exist in the folder:
#
#  ['mro_archive/ion/mromagr2007_001_2007_032.ion']
#
#  and will not be downloaded.
# ...Done.
# ===============================================================================================================
# Number of Loaded Existing + Downloaded Kernels: 7
# Number of Loaded Standard Kernels: 13
# ===============================================================================================================
# Cleaning Mission Archive...
# Done.
# Total number of loaded kernels: 20
# ======================================= Downloading MEX Data ==============================================
#
# =========================================== Folder(s) Creation ==================================================
# Folder: mex_archive/ already exists and will not be overwritten.
# ===============================================================================================================
#
# ===========================================================================================================
# Download MEX Radio Science Kernels:
# Checking URL: https://pds-geosciences.wustl.edu/mex/mex-m-mrs-1_2_3-v1/MEXMRS_0013/data/level02/closed_loop/ifms/dp2/
# --------------------------------------- EXISTING FILES CHECK ----------------------------------------------
# The following files already exist in the folder:
#
#  ['mex_archive/dp2/m32icl3l02_d2x_040231322_00.tab']
#
#  and will not be downloaded.
# ...Done.
# Checking URL: https://pds-geosciences.wustl.edu/mex/mex-m-mrs-1_2_3-v1/MEXMRS_0013/data/level02/closed_loop/dsn/dps/
# Checking URL: https://pds-geosciences.wustl.edu/mex/mex-m-mrs-1_2_3-v1/MEXMRS_0013/data/level02/closed_loop/dsn/dpx/
# ===========================================================================================================
# Download MEX Clock Kernels:
# File: mex_archive/sclk/MEX_241127_STEP.TSC already exists in: mex_archive/ and will not be downloaded.
# ===========================================================================================================
# Download MEX Frame Kernels:
# File: mex_archive/fk/MEX_V16.TF already exists in: mex_archive/ and will not be downloaded.
# File: mex_archive/fk/MEX_SCI_V01.TF already exists in: mex_archive/ and will not be downloaded.
# File: mex_archive/fk/MEX_RELAY_LOCATIONS_V03.TF already exists in: mex_archive/ and will not be downloaded.
# File: mex_archive/fk/MEX_DSK_SURFACES_V04.TF already exists in: mex_archive/ and will not be downloaded.
# File: mex_archive/fk/MEX_PFS_ROIS_V02.TF already exists in: mex_archive/ and will not be downloaded.
# ===========================================================================================================
# Download MEX SPK Kernels:
# Checking URL: https://spiftp.esac.esa.int/data/SPICE/MARS-EXPRESS/kernels/spk/
# --------------------------------------- EXISTING FILES CHECK ---------------------------------------------
#
# The following files already exist in the folder:
#
#  ['mex_archive/spk/ORMM_T19_040201000000_00060.BSP', 'mex_archive/spk/ORMF_T19_031222_050328_00066.BSP', 'mex_archive/spk/ORMM_T19_031222180906_00052.BSP']
#
#  and will not be downloaded.
# ...Done.
# ===========================================================================================================
# Download MEX CK Kernels:
# Checking URL: https://spiftp.esac.esa.int/data/SPICE/MARS-EXPRESS/kernels/ck/
# --------------------------------------- EXISTING FILES CHECK ---------------------------------------------
#
# The following files already exist in the folder:
#
#  ['mex_archive/ck/ATNM_MEASURED_040101_050101_V03.BC']
#
#  and will not be downloaded.
# Unwanted filename found: ATNM_MEASURED_2011_V04.BC. Skipping... [Do not worry! ;)]
# Unwanted filename found: ATNM_MEASURED_2012_V04.BC. Skipping... [Do not worry! ;)]
# Unwanted filename found: ATNM_MEASURED_2013_V04.BC. Skipping... [Do not worry! ;)]
# Unwanted filename found: ATNM_MEASURED_2015_V04.BC. Skipping... [Do not worry! ;)]
# Unwanted filename found: ATNM_MEASURED_2016_V04.BC. Skipping... [Do not worry! ;)]
# Unwanted filename found: ATNM_MEASURED_2017_V02.BC. Skipping... [Do not worry! ;)]
# Unwanted filename found: ATNM_MEASURED_2019_V03.BC. Skipping... [Do not worry! ;)]
# Unwanted filename found: ATNM_MEASURED_2020_V03.BC. Skipping... [Do not worry! ;)]
# Unwanted filename found: ATNM_MEASURED_2021_V02.BC. Skipping... [Do not worry! ;)]
# Unwanted filename found: ATNM_MEASURED_2022_V01.BC. Skipping... [Do not worry! ;)]
# Unwanted filename found: ATNM_MEASURED_2023_V01.BC. Skipping... [Do not worry! ;)]
# ...Done.
# ===========================================================================================================
# Download MEX Tropospheric and Ionospheric Corrections Files
# File: mex_archive/met/m32icl1l1b_met_040231119_00.tab already exists in: mex_archive/ and will not be downloaded.
# File: mex_archive/met/m32icl1l1b_met_040231150_00.tab already exists in: mex_archive/ and will not be downloaded.
# File: mex_archive/met/m32icl1l1b_met_040231220_00.tab already exists in: mex_archive/ and will not be downloaded.
# File: mex_archive/met/m32icl1l1b_met_040231321_00.tab already exists in: mex_archive/ and will not be downloaded.
# File: mex_archive/met/m32icl2l1b_met_040231120_00.tab already exists in: mex_archive/ and will not be downloaded.
# File: mex_archive/met/m32icl2l1b_met_040231222_00.tab already exists in: mex_archive/ and will not be downloaded.
# File: mex_archive/met/m32icl2l1b_met_040231321_00.tab already exists in: mex_archive/ and will not be downloaded.
# File: mex_archive/met/m32icl3l1b_met_040231121_00.tab already exists in: mex_archive/ and will not be downloaded.
# File: mex_archive/met/m32icl3l1b_met_040231221_00.tab already exists in: mex_archive/ and will not be downloaded.
# File: mex_archive/met/m32icl3l1b_met_040231322_00.tab already exists in: mex_archive/ and will not be downloaded.
# -----------------------------------------------------------------------------------------------------------
# All requested, relevant and previously non-existing MEX files have been now downloaded. Enjoy!
# Number of Loaded Existing + Downloaded + Standard Kernels: 40
# ===============================================================================================================
# Cleaning Mission Archive...
# Done.
# Total number of loaded kernels: 40
# ======================================= Downloading JUICE Data ==============================================
#
# =========================================== Folder(s) Creation ==================================================
# Folder: juice_archive/ already exists and will not be overwritten.
# ===============================================================================================================
#
# ===========================================================================================================
# Download JUICE Clock Files:
# Warning: Clock Kernel Ambiguity Found: ['https://spiftp.esac.esa.int/data/SPICE/JUICE/kernels/sclk/juice_fict_160326_v02.tsc', 'https://spiftp.esac.esa.int/data/SPICE/JUICE/kernels/sclk/juice_step_241112_v01.tsc'].
# Warning: Clock Kernel Ambiguity Found: ['https://spiftp.esac.esa.int/data/SPICE/JUICE/kernels/sclk/juice_fict_160326_v02.tsc', 'https://spiftp.esac.esa.int/data/SPICE/JUICE/kernels/sclk/juice_step_241112_v01.tsc'].
# File: juice_archive/sclk/juice_fict_160326_v02.tsc already exists in: juice_archive/ and will not be downloaded.
# File: juice_archive/sclk/juice_step_241112_v01.tsc already exists in: juice_archive/ and will not be downloaded.
# File: juice_archive/sclk/juice_fict_160326_v02.tsc already exists in: juice_archive/ and will not be downloaded.
# File: juice_archive/sclk/juice_step_241112_v01.tsc already exists in: juice_archive/ and will not be downloaded.
# ===========================================================================================================
# Download JUICE Frame Files:
# File: juice_archive/fk/juice_v41.tf already exists in: juice_archive/ and will not be downloaded.
# File: juice_archive/fk/juice_events_crema_5_1_150lb_23_1_v02.tf already exists in: juice_archive/ and will not be downloaded.
# File: juice_archive/fk/juice_ops_v11.tf already exists in: juice_archive/ and will not be downloaded.
# File: juice_archive/fk/juice_stations_topo_v01.tf already exists in: juice_archive/ and will not be downloaded.
# File: juice_archive/fk/juice_dsk_surfaces_v11.tf already exists in: juice_archive/ and will not be downloaded.
# File: juice_archive/fk/juice_sci_v17.tf already exists in: juice_archive/ and will not be downloaded.
# File: juice_archive/fk/juice_roi_v02.tf already exists in: juice_archive/ and will not be downloaded.
# ===========================================================================================================
# Download JUICE Orientation Kernels:
# File: juice_archive/ck/juice_mga_crema_5_1_150lb_23_1_baseline_v04.bc already exists in: juice_archive/ and will not be downloaded.
# File: juice_archive/ck/juice_sa_crema_5_1_150lb_23_1_baseline_v04.bc already exists in: juice_archive/ and will not be downloaded.
# File: juice_archive/ck/juice_sc_crema_5_1_150lb_23_1_baseline_v03.bc already exists in: juice_archive/ and will not be downloaded.
# Checking URL: https://spiftp.esac.esa.int/data/SPICE/JUICE/kernels/ck/
# --------------------------------------- EXISTING FILES CHECK ---------------------------------------------
#
# The following files already exist in the folder:
#
#  ['juice_archive/ck/juice_sc_meas_230701_230730_s230628_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230725_s230628_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230702_s230504_v01.bc', 'juice_archive/ck/juice_mga_crema_5_1_150lb_23_1_baseline_v04.bc', 'juice_archive/ck/juice_sc_meas_230701_230705_s230504_v01.bc', 'juice_archive/ck/juice_sc_meas_230801_230831_s240507_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230704_s230504_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230723_s230628_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230731_s240507_v01.bc', 'juice_archive/ck/juice_sa_crema_5_1_150lb_23_1_baseline_v04.bc', 'juice_archive/ck/juice_sc_meas_230801_230814_s230802_v01.bc', 'juice_archive/ck/juice_sc_meas_230801_230801_s230802_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230709_s230504_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230706_s230504_v01.bc', 'juice_archive/ck/juice_sc_crema_5_1_150lb_23_1_baseline_v03.bc', 'juice_archive/ck/juice_sc_meas_230801_230806_s230802_v01.bc', 'juice_archive/ck/juice_sc_meas_230801_230813_s230802_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230720_s230628_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230707_s230504_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230727_s230628_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230708_s230504_v01.bc', 'juice_archive/ck/juice_sc_meas_230801_230808_s230802_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230713_s230628_v01.bc', 'juice_archive/ck/juice_sc_meas_230801_230827_s230802_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230712_s230628_v01.bc', 'juice_archive/ck/juice_sc_meas_230801_230820_s230802_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230703_s230504_v02.bc', 'juice_archive/ck/juice_sc_meas_230801_230830_s230802_v01.bc', 'juice_archive/ck/juice_sc_meas_230414_240101_s231127_v01.bc', 'juice_archive/ck/juice_sc_meas_230801_230823_s230802_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230711_s230628_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230719_s230628_v01.bc']
#
#  and will not be downloaded.
# Unwanted filename found: juice_mga_zero_f20160326_v01.bc. Skipping... [Do not worry! ;)]
# Unwanted filename found: juice_mga_zero_f20160326_v02.bc. Skipping... [Do not worry! ;)]
# Unwanted filename found: juice_mga_zero_f20160326_v03.bc. Skipping... [Do not worry! ;)]
# Unwanted filename found: juice_sa_zero_f20160326_v00.bc. Skipping... [Do not worry! ;)]
# ...Done.
# ===========================================================================================================
# Download JUICE SPK Kernels:
# Checking URL: https://spiftp.esac.esa.int/data/SPICE/JUICE/kernels/spk/
# --------------------------------------- EXISTING FILES CHECK ---------------------------------------------
#
# The following files already exist in the folder:
#
#  ['juice_archive/spk/juice_orbc_000076_230414_310721_v01.bsp', 'juice_archive/spk/juice_orbc_000026_230413_310721_v04.bsp', 'juice_archive/spk/juice_orbc_000003_230405_310721_v01.bsp']
#
#  and will not be downloaded.
# ...Done.
# ---------------------------------------------
# No Ancillary Files to Load.
# No Radio Science Files to Load.
# Number of Loaded Existing + Downloaded + Standard Kernels: 89
# ===============================================================================================================
# Cleaning Mission Archive...
# Done.
# Total number of loaded kernels: 89

# %% [markdown]
# ## Loaded Kernels for MRO, MEX and JUICE (Existing + Downloaded)
# Last, you can print the list of existing + downloaded files.

# %%
print(f'MRO Kernels: {kernel_files_mro}\n')
print(f'MRO Radio Science: {radio_science_files_mro}\n')
print(f'MRO Ancillary: {ancillary_files_mro}\n')

print(f'MEX Kernels: {kernel_files_mex}\n')
print(f'MEX Radio Science: {radio_science_files_mex}\n')
print(f'MEX Ancillary: {ancillary_files_mex}\n')

print(f'JUICE Kernels: {kernel_files_juice}\n')
print(f'JUICE Radio Science: {radio_science_files_juice}\n') # it will be empty for now... (no Radio Science yet available on the server)
print(f'JUICE Ancillary: {ancillary_files_juice}\n') # it will be empty for now... (no Ancillary files yet available on the server)
# Out:
# MRO Kernels: {'sclk': ['mro_archive/sclk/mro_sclkscet_00112_65536.tsc'], 'fk': ['mro_archive/fk/mro_v16.tf'], 'spk': ['mro_archive/spk/mro_psp2.bsp', 'mro_archive/spk/mro_struct_v10.bsp'], 'ck': ['mro_archive/ck/mro_sc_psp_070102_070108.bc']}
#
# MRO Radio Science: {'odf': ['mro_archive/odf/mromagr2007_004_1801xmmmv1.odf', 'mro_archive/odf/mromagr2007_003_0845xmmmv1.odf']}
#
# MRO Ancillary: {'tro': ['mro_archive/tro/mromagr2007_001_2007_032.tro'], 'ion': ['mro_archive/ion/mromagr2007_001_2007_032.ion']}
#
# MEX Kernels: {'sclk': ['mex_archive/sclk/MEX_241127_STEP.TSC'], 'fk': ['mex_archive/fk/MEX_V16.TF', 'mex_archive/fk/MEX_SCI_V01.TF', 'mex_archive/fk/MEX_RELAY_LOCATIONS_V03.TF', 'mex_archive/fk/MEX_DSK_SURFACES_V04.TF', 'mex_archive/fk/MEX_PFS_ROIS_V02.TF'], 'spk': ['mex_archive/spk/ORMM_T19_040201000000_00060.BSP', 'mex_archive/spk/ORMF_T19_031222_050328_00066.BSP', 'mex_archive/spk/ORMM_T19_031222180906_00052.BSP'], 'ck': ['mex_archive/ck/ATNM_MEASURED_040101_050101_V03.BC']}
#
# MEX Radio Science: {'ifms_dp2': ['mex_archive/dp2/m32icl3l02_d2x_040231322_00.tab']}
v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230711_s230628_v01.bc', 'juice_archive/ck/juice_sc_meas_230701_230719_s230628_v01.bc'], 'spk': ['juice_archive/spk/juice_orbc_000076_230414_310721_v01.bsp', 'juice_archive/spk/juice_orbc_000026_230413_310721_v04.bsp', 'juice_archive/spk/juice_orbc_000003_230405_310721_v01.bsp']}
#
# JUICE Radio Science: {}
#
# JUICE Ancillary: {}

# %% [markdown]
# ## Cassini Downloader (with Custom Output)
#
# ### Set Flybys for Downloading
#
# The most valuable data collected for Cassini is probably the one related to the various flybys of the Moons of Saturn.
# For this reason, in order to retrieve Cassini data, we will require the name of the flyby data the user wishes to download, rather than a start and end date (see **Notes 5 and 6** for info on the supported flybys).
#
# ### Download Cassini Flyby Files
# We can call the function "get_mission_files" with 'Cassini' as input_mission. This call **will print a comprehensive table of supported flybys to choose from**, and the user will be asked to manually input the name of one of them.
#
# ### Flyby Data Output Division
#
# The default output folder will be named `cassini_archive/MOON_NAME/FLYBY_ID/`, where `MOON_NAME` is the flyby moon, and `FLYBY_ID` is the denomination of each downloaded flyby (e.g. T011, T022). Each subfolder will contain kernel ancillary and radio science subdirectories. In this example, we will download files from the flyby T011, and we will store them in the custom path: `'CASSINI_CUSTOM_ARCHIVE/'`
#
# **Note 5: Supported Flyby Moons**
#
# For now, only Titan Flybys are supported.
#
# **Note 6: flyby_IDs types**
#
# `flyby_IDs` can be:
# 1) a list made of single flybys like: `flyby_IDs = ['T011', 'T022']` or `flyby_IDs = ['T011']`
# 2) a single string object like: `flyby_IDs = 'T011'` (not a list)
# 3) a list made of all flybys performed at a given moon: `flyby_IDs = ['ALL_TITAN']`
# 4) a single string object like: `flyby_IDs = 'ALL_TITAN'`
# 5) a mixed list like: `flyby_IDs = ['T011', 'ALL_TITAN']`
#
# As mentioned above in *Download Cassini Flyby Files*, **you can also decide not to specify any flyby_ID**.
# In this case, **a table will be printed out** from which you will be able to interactively select the flyby you're interested in.
#
# **Note 7: Custom Output**
#
# As we mentioned above, the **default** output folder will be: `cassini_archive/MOON_NAME/FLYBY_ID/`
# The user can still define a custom output path using the flag `custom_output` in the `get_mission_files` function. The output files will then be found in: `custom_path/MOON_NAME/FLYBY_ID/`

# %%
# Download Cassini Titan Flyby T011 Files specifying './CASSINI_ARCHIVE/' as custom output
flyby_IDs = 'T011'
kernel_files_cassini, radio_science_files_cassini, ancillary_files_cassini = object.get_mission_files(input_mission = 'cassini', flyby_IDs = flyby_IDs, custom_output = 'CASSINI_CUSTOM_ARCHIVE/')
print(f'Total number of loaded kernels: {spice.get_total_count_of_kernels_loaded()}')
# Out:
# ======================================= Downloading CASSINI Data ==============================================
#
# =========================================== Folder(s) Creation ==================================================
# Folder: CASSINI_CUSTOM_ARCHIVE/ already exists and will not be overwritten.
# ===============================================================================================================
#
# ===========================================================================================================
# Download CASSINI Kernels (ck, spk) Ancillary Files (eop, ion, tro) and Radio Science (odf) files from PDS Atmosphere Node:
# Downloading: 'https://atmos.nmsu.edu/pdsd/archive/data/co-ssa-rss-1-tigr3-v10/cors_0133/tigr3_ancillary/ckf/s18tige2006_057_2006_062.ckf' to: CASSINI_CUSTOM_ARCHIVE/TITAN/T011/ck/S18TIGE2006_057_2006_062.CKF
# ## Loaded Kernels for Cassini Titan Flyby (Existing + Downloaded)
# Last, you can print the list of existing + downloaded files.

# %%
print(f'CASSINI Kernels: {kernel_files_cassini}\n')
print(f'CASSINI Radio Science: {radio_science_files_cassini}\n')
print(f'CASSINI Ancillary: {ancillary_files_cassini}\n')
# Out:
# CASSINI Kernels: {'ck': ['CASSINI_CUSTOM_ARCHIVE/TITAN/T011/ck/S18TIGE2006_057_2006_062.ck', 'CASSINI_CUSTOM_ARCHIVE/TITAN/T011/ck/S19TIGE2006_075_2006_079.ck'], 'spk': ['CASSINI_CUSTOM_ARCHIVE/TITAN/T011/spk/S18TIGE2006_036_2006_068.bsp', 'CASSINI_CUSTOM_ARCHIVE/TITAN/T011/spk/S19TIGE2006_068_2006_099.bsp'], 'fk': ['CASSINI_CUSTOM_ARCHIVE/TITAN/T011/fk/cas_v43.tf']}
#
# CASSINI Radio Science: {'odf': ['CASSINI_CUSTOM_ARCHIVE/TITAN/T011/odf/S18TIGM2006_058_0005X25MV1.ODF']}
#
# CASSINI Ancillary: {'eop': ['CASSINI_CUSTOM_ARCHIVE/TITAN/T011/eop/S18TIGE2005_141_2006_142.EOP'], 'ion': ['CASSINI_CUSTOM_ARCHIVE/TITAN/T011/ion/S18TIGE2006_032_2006_059.ION', 'CASSINI_CUSTOM_ARCHIVE/TITAN/T011/ion/S19TIGE2006_060_2006_090.ION'], 'tro': ['CASSINI_CUSTOM_ARCHIVE/TITAN/T011/tro/S18TIGE2006_032_2006_059.TRO', 'CASSINI_CUSTOM_ARCHIVE/TITAN/T011/tro/S18TIGE2006_060_2006_080.TRO']}

# %% [markdown]
# ## GRAIL-A and GRAIL-B Downloader (with Custom Output)
# As we mentioned above, you can also download GRAIL data for both GRAIL-A and GRAIL-B spacecraft. These can be downloaded as usually via the command: `get_mission_files`, specifying either: 'grail-a' or 'grail_b' as `input_mission`. Two folders will be created by default: `grail_archive/grail-a` and `grail_archive/grail-b`. However, you can still choose your own custom output folder. Let's call it `'GRAIL_ARCHIVE'`.

# %%
start_date_grail_a = datetime(2012, 4, 6)
end_date_grail_a = datetime(2012, 4, 12)

start_date_grail_b = datetime(2012, 5, 6)
end_date_grail_b = datetime(2012, 6, 12)

kernel_files_grail_a, radio_science_files_grail_a, ancillary_files_grail_a = object.get_mission_files(input_mission = 'grail-a', start_date = start_date_grail_a, end_date = end_date_grail_a, custom_output = './GRAIL_ARCHIVE')         
print(f'Total number of loaded kernels: {spice.get_total_count_of_kernels_loaded()}')
kernel_files_grail_b, radio_science_files_grail_b, ancillary_files_grail_b = object.get_mission_files(input_mission = 'grail-b', start_date = start_date_grail_b, end_date = end_date_grail_b, custom_output = './GRAIL_ARCHIVE')         
print(f'Total number of loaded kernels: {spice.get_total_count_of_kernels_loaded()}')
# Out:
# ======================================= Downloading GRAIL-A Data ==============================================
#
# =========================================== Folder(s) Creation ==================================================
# Creating Local Folder: ./GRAIL_ARCHIVE/grail-a and its subfolders (kernels and radio)...
# Folder: ./GRAIL_ARCHIVE/grail-a already exists and will not be overwritten.
# ===============================================================================================================
#
# ===========================================================================================================
# Download GRAIL-A ODF files:
# Checking URL: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/gralugf2012_097_0235smmmv1.odf to: ./GRAIL_ARCHIVE/grail-a/odf/gralugf2012_097_0235smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/gralugf2012_099_0407smmmv1.odf to: ./GRAIL_ARCHIVE/grail-a/odf/gralugf2012_099_0407smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/gralugf2012_100_0540smmmv1.odf to: ./GRAIL_ARCHIVE/grail-a/odf/gralugf2012_100_0540smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/gralugf2012_101_0235smmmv1.odf to: ./GRAIL_ARCHIVE/grail-a/odf/gralugf2012_101_0235smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/gralugf2012_102_0358smmmv1.odf to: ./GRAIL_ARCHIVE/grail-a/odf/gralugf2012_102_0358smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/gralugf2012_103_0145smmmv1.odf to: ./GRAIL_ARCHIVE/grail-a/odf/gralugf2012_103_0145smmmv1.odf
# ...Done.
# ===========================================================================================================
# Download GRAIL-A Clock Kernels:
# Warning: Clock Kernel Ambiguity Found: ['https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/sclk/gra_sclkscet_00013.tsc', 'https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/sclk/grb_sclkscet_00020.tsc'].
# Warning: Clock Kernel Ambiguity Found: ['https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/sclk/gra_sclkscet_00013.tsc', 'https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/sclk/grb_sclkscet_00020.tsc'].
# Downloading File: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/sclk/gra_sclkscet_00013.tsc to: ./GRAIL_ARCHIVE/grail-a/sclk/gra_sclkscet_00013.tsc
# Downloading File: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/sclk/grb_sclkscet_00020.tsc to: ./GRAIL_ARCHIVE/grail-a/sclk/grb_sclkscet_00020.tsc
# File: ./GRAIL_ARCHIVE/grail-a/sclk/gra_sclkscet_00013.tsc already exists in: ./GRAIL_ARCHIVE/grail-a and will not be downloaded.
# File: ./GRAIL_ARCHIVE/grail-a/sclk/grb_sclkscet_00020.tsc already exists in: ./GRAIL_ARCHIVE/grail-a and will not be downloaded.
# ===========================================================================================================
# Download GRAIL-A Frame Kernels:
# Downloading File: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/fk/grail_v07.tf to: ./GRAIL_ARCHIVE/grail-a/fk/grail_v07.tf
# ===========================================================================================================
# Download GRAIL-A Manoeuver Files:
# Downloading File: https://pds-geosciences.wustl.edu/grail/grail-l-lgrs-2-edr-v1/grail_0001/level_0/2012_04_06/mas00_2012_04_06_a_04.asc to: ./GRAIL_ARCHIVE/grail-a/manoeuver/mas00_2012_04_06_a_04.asc
# ===========================================================================================================
# Download GRAIL-A SPK Kernels:
# Checking URL: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/spk/
# Downloading: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/spk/grail_120301_120529_sci_v02.bsp to: ./GRAIL_ARCHIVE/grail-a/spk/grail_120301_120529_sci_v02.bsp
# ...Done.
# ===========================================================================================================
# Download GRAIL-A Orientation Kernels:
# Checking URL: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/ck/
# Downloading: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/ck/gra_rec_120402_120408.bc to: ./GRAIL_ARCHIVE/grail-a/ck/gra_rec_120402_120408.bc
# Downloading: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/ck/gra_rec_120409_120415.bc to: ./GRAIL_ARCHIVE/grail-a/ck/gra_rec_120409_120415.bc
# ...Done.
# ===========================================================================================================
# Download GRAIL-A Tropospheric Corrections Files
# Checking URL: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/ancillary/tro/
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/ancillary/tro/grxlugf2012_092_2012_122.tro to: ./GRAIL_ARCHIVE/grail-a/tro/grxlugf2012_092_2012_122.tro
# ...Done.
# ===========================================================================================================
# Download GRAIL-A Ionospheric Corrections Files
# Checking URL: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/ancillary/ion/
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/ancillary/ion/gralugf2012_092_2012_122.ion to: ./GRAIL_ARCHIVE/grail-a/ion/gralugf2012_092_2012_122.ion
# ...Done.
# Number of Loaded Existing + Downloaded + Standard Kernels: 109
# ===============================================================================================================
# Cleaning Mission Archive...
# Done.
# Total number of loaded kernels (GRAIL-A): 109
# ======================================= Downloading GRAIL-B Data ==============================================
#
# =========================================== Folder(s) Creation ==================================================
# Creating Local Folder: ./GRAIL_ARCHIVE/grail-b and its subfolders (kernels and radio)...
# Folder: ./GRAIL_ARCHIVE/grail-b already exists and will not be overwritten.
# ===============================================================================================================
#
# ===========================================================================================================
# Download GRAIL-B ODF files:
# Checking URL: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_128_0520smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_128_0520smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_129_1044smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_129_1044smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_130_1320smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_130_1320smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_131_1605smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_131_1605smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_132_1327smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_132_1327smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_133_1307smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_133_1307smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_134_1020smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_134_1020smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_135_1028smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_135_1028smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_136_1102smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_136_1102smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_137_1245smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_137_1245smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_138_1132smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_138_1132smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_139_1206smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_139_1206smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_140_1619smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_140_1619smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_142_1615smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_142_1615smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_143_1623smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_143_1623smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_144_0800smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_144_0800smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_145_1637smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_145_1637smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_146_1032smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_146_1032smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_148_1215smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_148_1215smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_151_1519smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_151_1519smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_152_1320smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_152_1320smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_153_1740smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_153_1740smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_154_1407smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_154_1407smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_155_0829smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_155_0829smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_156_1155smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_156_1155smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_157_0855smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_157_0855smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_159_1345smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_159_1345smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_160_1616smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_160_1616smmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/grblugf2012_164_0152smmmv1.odf to: ./GRAIL_ARCHIVE/grail-b/odf/grblugf2012_164_0152smmmv1.odf
# ...Done.
# ===========================================================================================================
# Download GRAIL-B Clock Kernels:
# Warning: Clock Kernel Ambiguity Found: ['https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/sclk/gra_sclkscet_00013.tsc', 'https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/sclk/grb_sclkscet_00020.tsc'].
# Warning: Clock Kernel Ambiguity Found: ['https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/sclk/gra_sclkscet_00013.tsc', 'https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/sclk/grb_sclkscet_00020.tsc'].
# Downloading File: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/sclk/gra_sclkscet_00013.tsc to: ./GRAIL_ARCHIVE/grail-b/sclk/gra_sclkscet_00013.tsc
# Downloading File: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/sclk/grb_sclkscet_00020.tsc to: ./GRAIL_ARCHIVE/grail-b/sclk/grb_sclkscet_00020.tsc
# File: ./GRAIL_ARCHIVE/grail-b/sclk/gra_sclkscet_00013.tsc already exists in: ./GRAIL_ARCHIVE/grail-b and will not be downloaded.
# File: ./GRAIL_ARCHIVE/grail-b/sclk/grb_sclkscet_00020.tsc already exists in: ./GRAIL_ARCHIVE/grail-b and will not be downloaded.
# ===========================================================================================================
# Download GRAIL-B Frame Kernels:
# Downloading File: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/fk/grail_v07.tf to: ./GRAIL_ARCHIVE/grail-b/fk/grail_v07.tf
# ===========================================================================================================
# Download GRAIL-B Manoeuver Files:
# Downloading File: https://pds-geosciences.wustl.edu/grail/grail-l-lgrs-2-edr-v1/grail_0001/level_0/2012_04_06/mas00_2012_04_06_a_04.asc to: ./GRAIL_ARCHIVE/grail-b/manoeuver/mas00_2012_04_06_a_04.asc
# ===========================================================================================================
# Download GRAIL-B SPK Kernels:
# Checking URL: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/spk/
# Downloading: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/spk/grail_120301_120529_sci_v02.bsp to: ./GRAIL_ARCHIVE/grail-b/spk/grail_120301_120529_sci_v02.bsp
# Downloading: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/spk/grail_120529_120830_nav_v01.bsp to: ./GRAIL_ARCHIVE/grail-b/spk/grail_120529_120830_nav_v01.bsp
# ...Done.
# ===========================================================================================================
# Download GRAIL-B Orientation Kernels:
# Checking URL: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/ck/
# Downloading: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/ck/grb_rec_120430_120506.bc to: ./GRAIL_ARCHIVE/grail-b/ck/grb_rec_120430_120506.bc
# Downloading: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/ck/grb_rec_120507_120513.bc to: ./GRAIL_ARCHIVE/grail-b/ck/grb_rec_120507_120513.bc
# Downloading: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/ck/grb_rec_120514_120520.bc to: ./GRAIL_ARCHIVE/grail-b/ck/grb_rec_120514_120520.bc
# Downloading: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/ck/grb_rec_120521_120527.bc to: ./GRAIL_ARCHIVE/grail-b/ck/grb_rec_120521_120527.bc
# Downloading: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/ck/grb_rec_120528_120603.bc to: ./GRAIL_ARCHIVE/grail-b/ck/grb_rec_120528_120603.bc
# Downloading: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/ck/grb_rec_120604_120610.bc to: ./GRAIL_ARCHIVE/grail-b/ck/grb_rec_120604_120610.bc
# Downloading: https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/data/ck/grb_rec_120611_120617.bc to: ./GRAIL_ARCHIVE/grail-b/ck/grb_rec_120611_120617.bc
# ...Done.
# ===========================================================================================================
# Download GRAIL-B Tropospheric Corrections Files
# Checking URL: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/ancillary/tro/
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/ancillary/tro/grxlugf2012_122_2012_153.tro to: ./GRAIL_ARCHIVE/grail-b/tro/grxlugf2012_122_2012_153.tro
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/ancillary/tro/grxlugf2012_153_2012_183.tro to: ./GRAIL_ARCHIVE/grail-b/tro/grxlugf2012_153_2012_183.tro
# ...Done.
# ===========================================================================================================
# Download GRAIL-B Ionospheric Corrections Files
# Checking URL: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/ancillary/ion/
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/ancillary/ion/grblugf2012_122_2012_153.ion to: ./GRAIL_ARCHIVE/grail-b/ion/grblugf2012_122_2012_153.ion
# Downloading: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/ancillary/ion/grblugf2012_153_2012_183.ion to: ./GRAIL_ARCHIVE/grail-b/ion/grblugf2012_153_2012_183.ion
# ...Done.
# Number of Loaded Existing + Downloaded + Standard Kernels: 126
# ===============================================================================================================
# Cleaning Mission Archive...
# Done.
# Total number of loaded kernels (GRAIL-B): 126

# %%
print(f'GRAIL-A Kernels: {kernel_files_grail_a}\n')
print(f'GRAIL-A Radio Science: {radio_science_files_grail_a}\n')
print(f'GRAIL-A Ancillary: {ancillary_files_grail_a}\n')
print('############################################################################################################################################\n')
print(f'GRAIL-B Kernels: {kernel_files_grail_b}\n')
print(f'GRAIL-B Radio Science: {radio_science_files_grail_b}\n')
print(f'GRAIL-B Ancillary: {ancillary_files_grail_b}\n')
# Out:
mmv1.odf', './GRAIL_ARCHIVE/grail-b/odf/grblugf2012_160_1616smmmv1.odf', './GRAIL_ARCHIVE/grail-b/odf/grblugf2012_164_0152smmmv1.odf']}
#
# GRAIL-B Ancillary: {'manoeuver': ['./GRAIL_ARCHIVE/grail-b/manoeuver/mas00_2012_04_06_a_04.asc'], 'tro': ['./GRAIL_ARCHIVE/grail-b/tro/grxlugf2012_122_2012_153.tro', './GRAIL_ARCHIVE/grail-b/tro/grxlugf2012_153_2012_183.tro'], 'ion': ['./GRAIL_ARCHIVE/grail-b/ion/grblugf2012_122_2012_153.ion', './GRAIL_ARCHIVE/grail-b/ion/grblugf2012_153_2012_183.ion']}

# %% [markdown]
# ## Customizing URLs and Patterns
# The folllowing cell shows how to download ck files for lro (not supported mission) specifying custom url and output folder.

# %%
custom_input_mission = 'lro'
custom_ck_url = 'https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/'
local_path = './lro_archive'
start_date_lro = datetime(2009, 7, 1)
end_date_lro = datetime(2009, 7, 10)

object.add_custom_mission_kernels_url(custom_input_mission, custom_ck_url)
object.dynamic_download_url_files_time_interval(custom_input_mission, local_path, start_date_lro, end_date_lro, custom_ck_url)
# Out:
# Checking URL: https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/
# --------------------------------------- EXISTING FILES CHECK ---------------------------------------------
#
# The following files already exist in the folder:
#
#  ['./lro_archive/ck/lrodv_2009186_2009213_v01.bc', './lro_archive/ck/lrosc_2009182_2009192_v01.bc', './lro_archive/ck/lrosc_2009172_2009182_v01.bc']
#
#  and will not be downloaded.
# ...Done.
# ['./lro_archive/ck/lrodv_2009186_2009213_v01.bc',
#  './lro_archive/ck/lrosc_2009182_2009192_v01.bc',
#  './lro_archive/ck/lrosc_2009172_2009182_v01.bc']

# %% [markdown]
# ## Downloading Custom Meta-Kernel Files for LRO (not supported mission)
# The following cell shows how to download all relevant files specified in a custom mission Meta-Kernel using custom inputs.
# The steps to be performed are:
#
# - Define the name of your `custom_input_mission`;
# - Add a `custom_meta_kernel_url` associated to the `custom_input_mission`;
# - Add a `custom_meta_kernel_pattern`  (or name, if you already know what's the exact name of the **meta-kernel** to be downloaded!);
# - Add the `custom_kernels_url` where kernels for your custom input mission are stored;
# - Define the custom path where you want to store your data;
# - Call the `get_mission_files` function as done for other missions alreayd, and do not forget the **flag**: `all_meta_kernel_files`;
# - Get popcorns, it's gonna take a while! 🍿

# %%
custom_input_mission = 'lro'
custom_meta_kernel_url = 'https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/extras/mk/'
custom_meta_kernel_pattern = 'lro_2024_v02.tm'
custom_kernels_url = 'https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/'

object.add_custom_mission_meta_kernel_url(custom_input_mission , custom_meta_kernel_url)
object.add_custom_mission_meta_kernel_pattern(custom_input_mission , custom_meta_kernel_pattern)
object.add_custom_mission_kernels_url(custom_input_mission, custom_kernels_url)
custom_local_path = './lro_archive'

object.get_mission_files(input_mission = custom_input_mission, 
                         custom_output = custom_local_path, all_meta_kernel_files = True)
# Out:
# {'mro': 'https://naif.jpl.nasa.gov/pub/naif/pds/data/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/', 'mex': 'https://spiftp.esac.esa.int/data/SPICE/MARS-EXPRESS/kernels/mk/', 'juice': 'https://spiftp.esac.esa.int/data/SPICE/JUICE/kernels/mk/', 'cassini': 'https://naif.jpl.nasa.gov/pub/naif/pds/data/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/', 'grail-a': 'https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/extras/mk/', 'grail-b': 'https://naif.jpl.nasa.gov/pub/naif/pds/data/grail-l-spice-6-v1.0/grlsp_1000/extras/mk/', 'lro': 'https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/extras/mk/'}
# {'mro': re.compile('^(mro)_(\\d{4})_v(\\d{2})\\.tm$'), 'mex': re.compile('MEX_OPS.TM'), 'juice': re.compile('juice_ops.tm'), 'cassini': re.compile('^cas_(\\d{4})_v(\\d{2})\\.tm$'), 'grail-a': re.compile('^grail_v(\\d{2})\\.tm$'), 'grail-b': re.compile('^grail_v(\\d{2})\\.tm$'), 'lro': re.compile('lro_2024_v02.tm')}
# ======================================= Downloading LRO Data ==============================================
#
# =========================================== Folder(s) Creation ==================================================
# Creating Local Folder: ./lro_archive and its subfolders (kernels and radio)...
# Folder: ./lro_archive already exists and will not be overwritten.
# ===============================================================================================================
#
# Downloading all Kernels from lro Latest Meta-Kernel File...
# LRO-L-SPICE-6-V1.0
# s ``data'
# ' with ``\'
#
# ./data
# KERNELS
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/lsk/naif0012.tls
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/sclk/lro_clkcor_2024171_v00.tsc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/pck/pck00010.tpc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/pck/moon_pa_de421_1900_2050.bpc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/fk/lro_dlre_frames_2010132_v04.tf
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/fk/lro_frames_2012255_v02.tf
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/fk/moon_assoc_me.tf
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/fk/moon_080317.tf
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ik/lro_crater_v03.ti
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ik/lro_dlre_v05.ti
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ik/lro_lamp_v03.ti
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ik/lro_lend_v00.ti
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ik/lro_lola_v00.ti
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ik/lro_lroc_v13.ti
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/spk/de421.bsp
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/spk/lrorg_2023349_2024075_v01.bsp
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/spk/lrorg_2024075_2024167_v01.bsp
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrodv_2023365_2024032_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrodv_2024031_2024061_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrodv_2024060_2024092_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrodv_2024091_2024122_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrodv_2024121_2024153_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrodv_2024152_2024183_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2023355_2024001_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024001_2024011_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024011_2024021_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024021_2024032_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024032_2024042_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024042_2024052_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024052_2024061_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024061_2024071_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024071_2024075_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024075_2024081_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024081_2024092_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024092_2024102_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024102_2024112_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024112_2024122_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024122_2024132_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024132_2024142_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024142_2024153_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024153_2024163_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrohg_2024163_2024167_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2023355_2024001_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024001_2024011_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024011_2024021_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024021_2024032_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024032_2024042_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024042_2024052_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024052_2024061_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024061_2024071_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024071_2024075_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024075_2024081_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024081_2024092_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024092_2024102_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024102_2024112_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024112_2024122_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024122_2024132_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024132_2024142_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024142_2024153_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024153_2024163_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosa_2024163_2024167_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2023355_2024001_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024001_2024011_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024011_2024021_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024021_2024032_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024032_2024042_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024042_2024052_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024052_2024061_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024061_2024071_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024071_2024075_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024075_2024081_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024081_2024092_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024092_2024102_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024102_2024112_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024112_2024122_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024122_2024132_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024132_2024142_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024142_2024153_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024153_2024163_v01.bc
# https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/ck/lrosc_2024163_2024167_v01.bc
# Downloading: 'https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/lsk/naif0012.tls' to: ./lro_archive/tls/naif0012.tls
# Downloading: 'https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/sclk/lro_clkcor_2024171_v00.tsc' to: ./lro_archive/tsc/lro_clkcor_2024171_v00.tsc
# Downloading: 'https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/pck/pck00010.tpc' to: ./lro_archive/tpc/pck00010.tpc
# Downloading: 'https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/pck/moon_pa_de421_1900_2050.bpc' to: ./lro_archive/bpc/moon_pa_de421_1900_2050.bpc
# Downloading: 'https://naif.jpl.nasa.gov/pub/naif/pds/data/lro-l-spice-6-v1.0/lrosp_1000/data/