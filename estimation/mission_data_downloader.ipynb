# %% [markdown]
# ## Objectives
#
# This script allows to download:
# 1) Spice (clock, frame, orientation, planetary) Kernels
# 2) Closed Loop Doppler Data (DSN and IFMS)
# 3) Ancillary Ionospheric and Tropospheric Data
#
# **NOTE 1 (Supported Missions and Relative Downloaded Data).**
#
# The following spice kernels:
#
# 1) **existing spice kernels** in the mission folder
# 2) (new) **downloaded spice kernels**
# 3) **standard TUDAT kernels** from [`spice.load_standard_kernels()`](https://py.api.tudat.space/en/latest/spice.html#tudatpy.interface.spice.load_standard_kernels)
#
# are loaded at the end of a run (some information is printed as output).
#
# List of currently supported input_missions:
# - **Mars Reconnnaissance Orbiter (MRO)** [Available: Spice Kernels, Doppler Data, Ancillary]
# - **Mars Express (MEX)** [Available: Spice Kernels, Doppler Data, Ancillary]
# - **Jupiter Icy Moons Explorer (JUICE)** [Available: Spice Kernels, Not Available (yet): Doppler Data, Ancillary]
# - **Cassini**
#
# Foreseen supported missions (in descending priority order, code yet to be developed):
#
# - Insight
# - VEX
# - GRAIL
# - LRO
#
# **NOTE 2. (Default and Custom Outputs)**
#
# The downloaded data for a given mission is stored (by default) in a folder named `<mission_name>_archive`. Subfolders are created automatically where Kernels, Radio Science Data and Ancillary Data are stored.
# The user can still define a custom output path passing the flag `custom_output` in the `get_mission_files` function. The output files will then be found in: `custom_path`
#
# **NOTE 3. (About DSN-TNF)**
#
# No DSN-TNF download functionality has been implemented (at least, not yet!)
#
# **Note 4: About spiceypy**
#
# A compiled version of TUDAT containing the `spiceypy` dependency is needed (if spiceypy is not present, you won't be able to download files for the Cassini mission)

# %% [markdown]
# ## Load required standard modules
# The required modules and dependencies are taken from the python file: `Mission_Data_Retriever_Class.py` present in the`tudatpy-examples/estimation` folder.

# %%
from mission_data_downloader_class import *

# %% [markdown]
# ## Create the LoadPDS Object
# First, we create the LoadPDS() object.

# %%
object = LoadPDS()

# %% [markdown]
# ## MRO Downloader (with Default Output)
#
# ### Set Time Interval(s) for Downloading
#
# Then we select the `start_date` and `end_date`, and we do so for each mission we wish to download (Cassini will be an exception due to the peculiar mission concept, see **Cassini Downloader** below). Of course, each mission has to come with its own dates, as operations are carried out over different periods.
#
# ### Download Mission Files (MRO, MEX, JUICE)
# Finally, we can call the function "get_mission_files".
# get_mro_files will download: clock kernels, orientation kernels, radio science (odf) files for mro
# get_mex_files will download: clock kernels, orientation kernels, radio science (ifms) files for mex
# get_juice_files will download: clock kernels, orientation kernels, for juice. No radio science data, cause none is yet available on the server (fdets retrieval is needed).
#
# **Note 5 (About MEX and JUICE Files Download)**
#
# Here, we will only showcase the downloading of MRO files. However, **if you wish to download files for MEX or JUICE**, you can simply **uncomment the corresponding lines** in the cell below! We have included those **just for you**!

# %%
start_date_juice = datetime(2023, 7, 1)
end_date_juice = datetime(2023, 8, 10)

start_date_mro = datetime(2007, 1, 3)
end_date_mro = datetime(2007, 1, 5)

start_date_mex = datetime(2004, 1, 3)
end_date_mex = datetime(2004,2, 7) 

# Download Mission Files with default output folder
# (only MRO is shown here. Uncomment the corresponding lines to download data for MEX and JUICE!)

kernel_files_mro, radio_science_files_mro, ancillary_files_mro = object.get_mission_files(input_mission = 'mro', start_date = start_date_mro, end_date = end_date_mro, custom_output = None)         
print(f'Total number of loaded kernels: {spice.get_total_count_of_kernels_loaded()}')

#kernel_files_mex, radio_science_files_mex, ancillary_files_mex = object.get_mission_files(input_mission = 'mex', start_date = start_date_mex, end_date = end_date_mex)         
#print(f'Total number of loaded kernels: {spice.get_total_count_of_kernels_loaded()}')

#kernel_files_juice, radio_science_files_juice, ancillary_files_juice = object.get_mission_files(input_mission = 'juice', start_date = start_date_juice, end_date = end_date_juice) 
#print(f'Total number of loaded kernels: {spice.get_total_count_of_kernels_loaded()}')
# Out:
# ======================================= Downloading MRO Data ==============================================
#
# =========================================== Folder(s) Creation ==================================================
# Creating Local Folder: mro_archive/ and its subfolders (kernels and radio)...
# Folder: mro_archive/ already exists and will not be overwritten.
# ===============================================================================================================
#
# ===========================================================================================================
# Download MRO ODF files:
# Checking URL: https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/
# Downloading: https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2007_003_0845xmmmv1.odf
# Downloading: https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2007_004_1801xmmmv1.odf
# ...Done.
# ===========================================================================================================
# Download MRO Clock Kernels:
# Downloading File: mro_archive/sclk/mro_sclkscet_00112_65536.tsc
# ===========================================================================================================
# Download MRO Frame Kernels:
# Downloading File: mro_archive/fk/mro_v16.tf
# ===========================================================================================================
# Download MRO SPK Kernels:
# Downloading File: mro_archive/spk/mro_psp2.bsp
# Downloading File: mro_archive/spk/mro_struct_v10.bsp
# ===========================================================================================================
# Download MRO Orientation Kernels:
# Checking URL: https://naif.jpl.nasa.gov/pub/naif/pds/data/mro-m-spice-6-v1.0/mrosp_1000/data/ck/
# Downloading mro_sc_psp_070102_070108.bc
# ...Done.
# ===========================================================================================================
# Download MRO Tropospheric Corrections Files
# Checking URL: https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/ancillary/tro/
# Downloading mromagr2007_001_2007_032.tro
# ...Done.
# ===========================================================================================================
# Download MRO Ionospheric Corrections Files
# Checking URL: https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/ancillary/ion/
# Downloading mromagr2007_001_2007_032.ion
# ...Done.
# ===============================================================================================================
# Number of Loaded Existing + Downloaded Kernels: 7
# Cleaning Mission Archive...
# Done.
# Number of Loaded Standard Kernels: 13
# ===============================================================================================================
# Total number of loaded kernels: 20

# %% [markdown]
# ## Loaded Kernels for MRO, MEX and JUICE (Existing + Downloaded)
# Last, you can print the list of existing + downloaded files.

# %%
print(f'MRO Kernels: {kernel_files_mro}\n')
print(f'MRO Radio Science: {radio_science_files_mro}\n')
print(f'MRO Ancillary: {ancillary_files_mro}\n')

#print(f'MEX Kernels: {kernel_files_mex}\n')
#print(f'MEX Radio Science: {radio_science_files_mex}\n')
#print(f'MEX Ancillary: {ancillary_files_mex}\n')

#print(f'JUICE Kernels: {kernel_files_juice}\n')
#print(f'JUICE Radio Science: {radio_science_files_juice}\n') # it will be empty for now... (no Radio Science yet available on the server)
#print(f'JUICE Ancillary: {ancillary_files_juice}\n') # it will be empty for now... (no Ancillary files yet available on the server)
# Out:
# MRO Kernels: {'sclk': ['mro_archive/sclk/mro_sclkscet_00112_65536.tsc'], 'fk': ['mro_archive/fk/mro_v16.tf'], 'spk': ['mro_archive/spk/mro_psp2.bsp', 'mro_archive/spk/mro_struct_v10.bsp'], 'ck': ['mro_archive/ck/mro_sc_psp_070102_070108.bc']}
#
# MRO Radio Science: {'odf': ['mro_archive/odf/mromagr2007_003_0845xmmmv1.odf', 'mro_archive/odf/mromagr2007_004_1801xmmmv1.odf']}
#
# MRO Ancillary: {'tro': ['mro_archive/tro/mromagr2007_001_2007_032.tro'], 'ion': ['mro_archive/ion/mromagr2007_001_2007_032.ion']}

# %% [markdown]
# ## Cassini Downloader (with Custom Output)
#
# ### Set Flybys for Downloading
#
# The most valuable data collected for Cassini is probably the one related to the various flybys of the Moons of Saturn.
# For this reason, in order to retrieve Cassini data, we will require the name of the flyby data the user wishes to download, rather than a start and end date (see **Notes 5 and 6** for info on the supported flybys).
#
# ### Download Cassini Flyby Files
# We can call the function "get_mission_files" with 'Cassini' as input_mission. This call will print a comprehensive table of supported flybys to choose from, and the user will be asked to manually input the name of one of them.
#
# ### Flyby Data Output Division
#
# The default output folder will be named `cassini_archive/MOON_NAME/FLYBY_ID/`, where `MOON_NAME` is the flyby moon, and `FLYBY_ID` is the denomination of each downloaded flyby (e.g. T011, T022). Each subfolder will contain kernel ancillary and radio science subdirectories. In this example, we will download files from the flyby T011, and we will store them in the custom path: `'CASSINI_CUSTOM_ARCHIVE/'`
#
# **Note 5: Supported Flyby Moons**
#
# For now, only Titan Flybys are supported.
#
# **Note 6: flyby_IDs types**
#
# `flyby_IDs` can be:
# 1) a list made of single flybys like: `flyby_IDs = ['T011', 'T022']` or `flyby_IDs = ['T011']`
# 2) a single string object like: `flyby_IDs = 'T011'` (not a list)
# 3) a list made of all flybys performed at a given moon: `flyby_IDs = ['ALL_TITAN']`
# 4) a single string object like: `flyby_IDs = 'ALL_TITAN'`
# 5) a mixed list like: `flyby_IDs = ['T011', 'ALL_TITAN']`
#
# **Note 7: Custom Output**
#
# As we mentioned above, the **default** output folder will be: `cassini_archive/MOON_NAME/FLYBY_ID/`
# The user can still define a custom output path using the flag `custom_output` in the `get_mission_files` function. The output files will then be found in: `custom_path/MOON_NAME/FLYBY_ID/`

# %%
# Download Cassini Titan Flyby T011 Files specifying './CASSINI_ARCHIVE/' as custom output
flyby_IDs = 'T011'
kernel_files_cassini, radio_science_files_cassini, ancillary_files_cassini = object.get_mission_files(input_mission = 'cassini', flyby_IDs = flyby_IDs, custom_output = 'CASSINI_CUSTOM_ARCHIVE/')
print(f'Total number of loaded kernels: {spice.get_total_count_of_kernels_loaded()}')
# Out:
# ======================================= Downloading CASSINI Data ==============================================
#
# =========================================== Folder(s) Creation ==================================================
# Creating Local Folder: CASSINI_CUSTOM_ARCHIVE/ and its subfolders (kernels and radio)...
# ===============================================================================================================
#
# ===========================================================================================================
# Download CASSINI Kernels (ck, spk) Ancillary Files (eop, ion, tro) and Radio Science (odf) files from PDS Atmosphere Node:
# Downloading 'https://atmos.nmsu.edu/pdsd/archive/data/co-ssa-rss-1-tigr3-v10/cors_0133/tigr3_ancillary/ckf/s18tige2006_057_2006_062.ckf' to CASSINI_CUSTOM_ARCHIVE/TITAN/T011/ck/S18TIGE2006_057_2006_062.CKF
# Downloading 'https://atmos.nmsu.edu/pdsd/archive/data/co-ssa-rss-1-tigr3-v10/cors_0133/tigr3_ancillary/ckf/s19tige2006_075_2006_079.ckf' to CASSINI_CUSTOM_ARCHIVE/TITAN/T011/ck/S19TIGE2006_075_2006_079.CKF
# Downloading 'https://atmos.nmsu.edu/pdsd/archive/data/co-ssa-rss-1-tigr3-v10/cors_0133/tigr3_ancillary/eop/s18tige2005_141_2006_142.eop' to CASSINI_CUSTOM_ARCHIVE/TITAN/T011/eop/S18TIGE2005_141_2006_142.EOP
# Downloading 'https://atmos.nmsu.edu/pdsd/archive/data/co-ssa-rss-1-tigr3-v10/cors_0133/tigr3_ancillary/ion/s18tige2006_032_2006_059.ion' to CASSINI_CUSTOM_ARCHIVE/TITAN/T011/ion/S18TIGE2006_032_2006_059.ION
# Downloading 'https://atmos.nmsu.edu/pdsd/archive/data/co-ssa-rss-1-tigr3-v10/cors_0133/tigr3_ancillary/ion/s19tige2006_060_2006_090.ion' to CASSINI_CUSTOM_ARCHIVE/TITAN/T011/ion/S19TIGE2006_060_2006_090.ION
# Downloading 'https://atmos.nmsu.edu/pdsd/archive/data/co-ssa-rss-1-tigr3-v10/cors_0133/tigr3_ancillary/spk/s18tige2006_036_2006_068.spk' to CASSINI_CUSTOM_ARCHIVE/TITAN/T011/spk/S18TIGE2006_036_2006_068.SPK
# Downloading 'https://atmos.nmsu.edu/pdsd/archive/data/co-ssa-rss-1-tigr3-v10/cors_0133/tigr3_ancillary/spk/s19tige2006_068_2006_099.spk' to CASSINI_CUSTOM_ARCHIVE/TITAN/T011/spk/S19TIGE2006_068_2006_099.SPK
# Downloading 'https://atmos.nmsu.edu/pdsd/archive/data/co-ssa-rss-1-tigr3-v10/cors_0133/tigr3_ancillary/tro/s18tige2006_032_2006_059.tro' to CASSINI_CUSTOM_ARCHIVE/TITAN/T011/tro/S18TIGE2006_032_2006_059.TRO
# Downloading 'https://atmos.nmsu.edu/pdsd/archive/data/co-ssa-rss-1-tigr3-v10/cors_0133/tigr3_ancillary/tro/s18tige2006_060_2006_080.tro' to CASSINI_CUSTOM_ARCHIVE/TITAN/T011/tro/S18TIGE2006_060_2006_080.TRO
# Downloading 'https://atmos.nmsu.edu/pdsd/archive/data/co-ssa-rss-1-tigr3-v10/cors_0133/tigr3_058/odf/s18tigm2006_058_0005x25mv1.odf' to CASSINI_CUSTOM_ARCHIVE/TITAN/T011/odf/S18TIGM2006_058_0005X25MV1.ODF
# ===========================================================================================================
# Download CASSINI Frame Kernels from NAIF:
# Downloading File: CASSINI_CUSTOM_ARCHIVE/TITAN/T011/fk/cas_v43.tf
# ===============================================================================================================
# Number of Loaded Existing + Downloaded Kernels: 10
# Cleaning Mission Archive...
# Done.
# Number of Loaded Standard Kernels: 13
# ===============================================================================================================
# Total number of loaded kernels: 23

# %% [markdown]
# ## Loaded Kernels for Cassini Titan Flyby (Existing + Downloaded)
# Last, you can print the list of existing + downloaded files.

# %%
print(f'CASSINI Kernels: {kernel_files_cassini}\n')
print(f'CASSINI Radio Science: {radio_science_files_cassini}\n')
print(f'CASSINI Ancillary: {ancillary_files_cassini}\n')
# Out:
# CASSINI Kernels: {'ck': ['CASSINI_CUSTOM_ARCHIVE/TITAN/T011/ck/S18TIGE2006_057_2006_062.ck', 'CASSINI_CUSTOM_ARCHIVE/TITAN/T011/ck/S19TIGE2006_075_2006_079.ck'], 'spk': ['CASSINI_CUSTOM_ARCHIVE/TITAN/T011/spk/S18TIGE2006_036_2006_068.bsp', 'CASSINI_CUSTOM_ARCHIVE/TITAN/T011/spk/S19TIGE2006_068_2006_099.bsp'], 'fk': ['CASSINI_CUSTOM_ARCHIVE/TITAN/T011/fk/cas_v43.tf']}
#
# CASSINI Radio Science: {'odf': ['CASSINI_CUSTOM_ARCHIVE/TITAN/T011/odf/S18TIGM2006_058_0005X25MV1.ODF']}
#
# CASSINI Ancillary: {'eop': ['CASSINI_CUSTOM_ARCHIVE/TITAN/T011/eop/S18TIGE2005_141_2006_142.EOP'], 'ion': ['CASSINI_CUSTOM_ARCHIVE/TITAN/T011/ion/S18TIGE2006_032_2006_059.ION', 'CASSINI_CUSTOM_ARCHIVE/TITAN/T011/ion/S19TIGE2006_060_2006_090.ION'], 'tro': ['CASSINI_CUSTOM_ARCHIVE/TITAN/T011/tro/S18TIGE2006_032_2006_059.TRO', 'CASSINI_CUSTOM_ARCHIVE/TITAN/T011/tro/S18TIGE2006_060_2006_080.TRO']}

# %% [markdown]
# ## GRAIL Downloader (with Default Output)

# %%
start_date_grail = datetime(2012, 4, 6)
end_date_grail = datetime(2012, 4, 12)

kernel_files_grail, radio_science_files_grail, ancillary_files_grail = object.get_mission_files(input_mission = 'grail', start_date = start_date_grail, end_date = end_date_grail, custom_output = None)         
print(f'Total number of loaded kernels: {spice.get_total_count_of_kernels_loaded()}')
# Out:
# ======================================= Downloading GRAIL Data ==============================================
#
# =========================================== Folder(s) Creation ==================================================
# Folder: grail_archive/ already exists and will not be overwritten.
# ===============================================================================================================
#
# ===========================================================================================================
# Download MRO ODF files:
# Checking URL: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/odf/
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_253_1429smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_255_0054smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_257_0051smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_259_0750smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_261_0745smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_263_0154smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_265_0735smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_267_0729smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_269_0723smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_271_0720smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_273_0712smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_275_0715smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_284_1428smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_290_1410smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_294_1348smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_298_1320smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_304_1325smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_306_1252smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_307_1507smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_312_1312smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_315_0652smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_316_0700smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_317_0536smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_318_0518smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_320_0133smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_322_0520smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_325_1320smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_328_1304smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_332_1320smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_337_0602smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_339_0601smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_341_0152smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_343_0613smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_346_1420smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_348_1404smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_351_0800smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_352_0807smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_353_0825smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_355_1000smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_357_0857smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_358_0920smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_360_1255smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_362_0252smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_364_0412smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2011_365_0500smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_001_0627smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_002_0402smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_004_0148smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_006_0106smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_007_1118smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_009_0447smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_011_0320smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_012_0553smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_014_0640smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_016_0924smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_018_0405smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_020_0620smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_022_0755smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_023_1623smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_025_0928smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_027_1150smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_029_0655smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_030_1230smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_032_0252smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_034_0533smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_035_0434smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_036_0538smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_037_0217smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_038_0136smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_040_0609smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_042_0540smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_044_0021smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_046_0258smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_047_0430smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_049_0554smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_051_0717smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_053_0905smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_055_0206smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_057_0425smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_058_0125smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_060_0634smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_061_1233smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_062_0141smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_063_0216smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_064_1026smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_065_1101smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_066_0100smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_067_0125smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_068_0210smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_069_0455smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_072_0648smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_073_0526smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_074_0603smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_075_0352smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_076_0351smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_079_1105smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_080_0601smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_081_1359smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_082_0311smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_083_0820smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_086_0330smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_087_1305smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_089_1615smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_091_0358smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_093_0400smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_094_0931smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_095_0435smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_096_0459smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_097_0235smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_099_0407smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_100_0540smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_101_0235smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_102_0358smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_103_0145smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_105_0352smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_107_0405smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_108_0450smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_109_1227smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_111_1332smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_114_0900smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_117_0300smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_119_0545smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_121_0155smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_122_1113smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_123_0607smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_124_0253smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_125_0400smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_126_0203smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_128_0233smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_129_1626smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_130_1702smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_131_1003smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_132_1313smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_133_1847smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_134_1536smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_135_1041smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_136_1139smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_137_1215smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_138_0845smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_139_1533smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_140_1923smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_141_1406smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_142_1555smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_143_2242smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_144_0800smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_145_1245smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_146_2001smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_148_0605smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_149_1445smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_151_1520smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_152_0213smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_152_0950smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_153_1300smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_154_0910smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_155_0830smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_156_0757smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_157_1418smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_159_1357smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_160_1417smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_163_1607smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_164_1608smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_166_0225smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_166_1805smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_167_1457smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_168_2000smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_170_0919smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_171_1556smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_172_2340smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_173_1529smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_174_1817smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_175_1000smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_177_1255smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_178_1820smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_180_1230smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_181_1316smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_182_2020smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_184_1419smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_185_1340smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_187_1418smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_188_1338smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_191_1044smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_192_1515smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_193_1559smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_194_1655smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_195_1748smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Could not parse file: gralugf2012_197_1447smmmv1.odf - Error: cannot unpack non-iterable NoneType object
# ...
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Nothing to download.
# ...Done.
# No ck files to download this time.
# ===========================================================================================================
# Download MRO Tropospheric Corrections Files
# Checking URL: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/ancillary/tro/
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Nothing to download.
# ...Done.
# No tropospheric files to download this time.
# ===========================================================================================================
# Download MRO Ionospheric Corrections Files
# Checking URL: https://pds-geosciences.wustl.edu/grail/grail-l-rss-2-edr-v1/grail_0201/ancillary/ion/
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# ['ck', 'dsk', 'spk', 'fk', 'mk', 'ik', 'lsk', 'pck', 'sclk', 'odf', 'ifms', 'dp2', 'dps', 'dpx', 'ion', 'tro', 'eop', 'manoeuver', 'antenna_switch']
# Nothing to download.
# ...Done.
# No ionospheric files to download this time.
# ===============================================================================================================
# Number of Loaded Existing + Downloaded Kernels: 4
# Cleaning Mission Archive...
# Done.
# Number of Loaded Standard Kernels: 13
# ===============================================================================================================
# Total number of loaded kernels: 17

# %%
print(f'GRAIL Kernels: {kernel_files_grail}\n')
print(f'GRAIL Radio Science: {radio_science_files_grail}\n')
print(f'GRAIL Ancillary: {ancillary_files_grail}\n')
# Out:
# GRAIL Kernels: {'sclk': ['grail_archive/sclk/gra_sclkscet_00014.tsc'], 'fk': ['grail_archive/fk/grail_v07.tf'], 'spk': ['grail_archive/spk/grail_120301_120529_sci_v02.bsp']}
#
# GRAIL Radio Science: {}
#
# GRAIL Ancillary: {'manoeuver': ['grail_archive/manoeuver/mas00_2012_04_06_a_04.asc']}
